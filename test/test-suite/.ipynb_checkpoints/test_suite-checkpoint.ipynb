# %% [markdown]
# # Importing the necessary python packages

# %%
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import numpy as np
import matplotlib as mpl
import glob
import matplotlib
from scipy.io import FortranFile
import struct
import os


shark_dir     =  '/Users/vg270045/Documents/Doctorat/Codes/Shark/shark'# Add the test suite path here
bin_dir       =  shark_dir+'/bin'       # Add the bin directory here
suite_dir     =  shark_dir+'/test/test-suite'
NUM_THREAD    = 8 # This depends on your machine, this is the number of threads you want to use with openmp

# %% [markdown]
# # Default compilation options for the tests

# %%
OPENMP     = 1    # We use the openmp speedup
SOLVER     = 2    # HLLD
SOLVERDUST = 0   # Huang & Bai 2021, if applicable ie if dust is included
RESOLUTION = 2048 # Default resolution for the 1D tests

default_compils={'OPENMP':OPENMP,"NUM_THREAD":NUM_THREAD,'SOLVER':SOLVER,'SOLVERDUST':SOLVERDUST,"RESOLUTION":RESOLUTION}

# %% [markdown]
# # Functions to read the data from shark

# %%
def read_var(filename,varname,size):
    f=open(filename+"/"+varname, "rb")
    dat = np.fromfile(f, dtype=np.float64, count=size, sep='')
    return dat

def read_parameter_file(fname="",evaluate=True,verbose=True,delimiter="="):
    # Read info file and create dictionary
    try:
        with open(fname) as f:
            content = f.readlines()
        f.close()
    except IOError:
        # Clean exit if the file was not found
        if verbose:
            print("File not found: "+fname)
        return 0
    infos={}
    for line in content:
        sp = line.split(delimiter)
        #print(sp)
        if len(sp) > 1:
            if evaluate:
                try:
                    infos[sp[0].strip()] = eval(sp[1].strip())
                except (NameError,SyntaxError):
                    infos[sp[0].strip()] = sp[1].strip()
            else:
                infos[sp[0].strip()] = sp[1].strip()
    return infos

def read_output(number,path='.'):
    
    if(number==-1):
        filelist = sorted(glob.glob(path+"/output*"))
        number = filelist[-1].split("_")[-1]
    print('Reading output '+str(number))
    data={}
    filename= path+"/output_"+ str(number).zfill(5)
    infos=read_parameter_file(fname=filename+'/info.dat')
    data['infos']=infos
    for key in infos:
        print(key+' = ',infos[key])
    
    NX          = infos["NX"]
    NY          = infos["NY"]
    NDUST       = infos["ndust"]
    GEOM        = infos['GEOM']
    GRIDSPACE   = infos['GRIDSPACE']
    CHARGING    = infos['charging']
    MHD         = infos['MHD']

    data['x']   = read_var(filename,'x',NX*NY)
    
    if(NY>1):
        data['y']   = read_var(filename,'y',NX*NY)
        data["xx"]  = np.linspace(np.amin(data["x"]),np.amax(data["x"]),NX)
        data["yy"]  = np.linspace(np.amin(data["y"]),np.amin(data["y"]),NY)
        data["xx"]  = np.linspace(0,1,NX)
        data["yy"]  = np.linspace(0,1,NY)
    
    vx   = read_var(filename,'v'  , NX*NY)
    vy   = read_var(filename,'vy' , NX*NY)
    P    = read_var(filename,'P'  , NX*NY)
    rho  = read_var(filename,'rho', NX*NY)
    if (MHD==1):
        Bx  = read_var(filename,'Bx', NX*NY)
        By  = read_var(filename,'By', NX*NY)
        Bz  = read_var(filename,'Bz', NX*NY)
        data['Bx'] = Bx
        data['By'] = By
        data['Bz'] = Bz



    if(NDUST>0):
        rhod   = read_var(filename,'rhod',  NX*NY*NDUST)
        vdx    = read_var(filename,'vd'  ,  NX*NY*NDUST)
        vdy    = read_var(filename,'vdy' ,  NX*NY*NDUST)
        sd     = read_var(filename,'sd',  NX*NY*NDUST)
  
        if(CHARGING>0):
            ni = read_var(filename,'ni' , NX*NY)
            ne = read_var(filename,'ne' , NX*NY)
            #eta_a = read_var(filename,'eta_a' , NX*NY)
            #eta_o = read_var(filename,'eta_o' , NX*NY)
            #eta_h = read_var(filename,'eta_h' , NX*NY)
        if(NDUST>1):

            for idust in range(NDUST):
                if(NY>1):
                    data['rhod'] = np.reshape(rhod_tot,(NY,NX),order = "C").T
                    data['rhod' + str(idust+1)]  = np.reshape(rhod[(idust)* NX * NY:(idust+1)*NX*NY],(NY,NX),order  = "C").T
                    data['vdx'  + str(idust+1)]  = np.reshape(vdx[(idust) * NX * NY:(idust+1)*NX*NY],(NY,NX),order  = "C").T
                    data['vdy'  + str(idust+1)]  = np.reshape(vdx[(idust) * NX * NY:(idust+1)*NX*NY],(NY,NX),order  = "C").T
                    data['sd'  + str(idust+1)]   = np.reshape(sd[(idust) * NX * NY:(idust+1)*NX*NY],(NY,NX),order  = "C").T
                else:
                    data['rhod' + str(idust+1)]  = rhod[(idust)* NX:(idust+1) * NX]
                    data['vdx'  + str(idust+1)]  = vdx[(idust) * NX:(idust+1) * NX]
                    data['vdy'  + str(idust+1)]  = vdy[(idust) * NX:(idust+1) * NX]
                    data['sd'  + str(idust+1)]   = sd[(idust) * NX:(idust+1) * NX]
        else:
            if(NY>1):
                data['rhod'] = np.reshape(rhod,(NY,NX),order = "C").T
                data['vdx']  = np.reshape(vdx,(NY,NX),order = "C") .T
                data['vdy']  = np.reshape(vdy,(NY,NX),order = "C") .T   
                data['sd']   = np.reshape(sd,(NY,NX),order = "C") .T   
                
            else:
                data['rhod'] = rhod
                data['vdx']  = vdx
                data['vdy']  = vdy
                data['sd']   = sd

    if(NY>1):     
        data['rho'] = np.reshape(rho,(NY,NX),order = "C").T
        data['vx']  = np.reshape(vx ,(NY,NX),order = "C").T
        data['vy']  = np.reshape(vy ,(NY,NX),order = "C").T
        
        if(CHARGING):
            data['ni']    = np.reshape(ni,(NY,NX),order = "C").T
            data['ne']    = np.reshape(ne,(NY,NX),order = "C").T
            #data['eta_a'] = np.reshape(eta_a,(NY,NX),order = "C").T
            #data['eta_o'] = np.reshape(eta_o,(NY,NX),order = "C").T
            #data['eta_h'] = np.reshape(eta_h,(NY,NX),order = "C").T     
    else:
        data['rho'] = rho
        data['vx']  = vx
        data['vy']  = vy
        data['P']   = P
        if(CHARGING>0):
            data['ni'] = ni
            data['ne'] = ne
            #data['eta_a'] = eta_a
            #data['eta_o'] = eta_o
            #data['eta_h'] = eta_h        

    if(NX==1):
        data['rhod'] = rhod
        data['rho']  = rho[0]
        data['sd']   = read_var(filename,'sd',  NX*NY*NDUST)
        if(CHARGING>0):
            data['ni'] = ni[0]
            data['ne'] = ne[0]
            #data['eta_a'] = eta_a[0]
            #data['eta_o'] = eta_o[0]
            #data['eta_h'] = eta_h[0]

    if(GEOM==2): 
        rmin = np.amin(data['x'])
        rmax = np.amax(data['x'])
        r=np.linspace(rmin,rmax,NX)
        if(GRIDSPACE==1):
            r=np.logspace(np.log10(rmin),np.log10(rmax),NX)
        data['r']=r
        data['theta']=np.linspace(0,2.*np.pi,NY)
    if(GEOM==4): 
        rmin = np.amin(data['x'])
        rmax = np.amax(data['x'])
        r=np.linspace(rmin,rmax,NX)
        if(GRIDSPACE==1):
            r=np.logspace(np.log10(rmin),np.log10(rmax),NX)
        data['r']=r
        data['z']=data['y']
    return data

import math

def truncate(number, digits) -> float:
    stepper = 10.0 ** digits
    return math.trunc(stepper * number) / stepper

# %% [markdown]
# # Functions to run the tests

# %%
def run_test(test='Sod-tube',options=default_compils,visu=True,flag_change=None):
    
    if(test=="Sod-tube"):
        flags="SETUP=SOD NX="+str(options["RESOLUTION"])+" NY=1 NGHOST=2 OPENMP="+str(options["OPENMP"])+" DEBUG=0 SOLVER="+str(options["SOLVER"])
        if(flag_change is not None):
            flags=flag_change
        print ('You are compiling with the options '+ flags )
        os.chdir(bin_dir)
        os.system("make clean && make "+flags)
        os.chdir(suite_dir+'/'+test)
        os.system('rm -rf output_*')
        os.system("export OMP_NUM_THREADS="+str(options["NUM_THREAD"])+";"+bin_dir+'/shark sod.nml')
        data_ana = np.loadtxt(suite_dir+'/'+test+'/solution.dat')
        
        x_ana    = data_ana[:,1]
        rho_ana  = data_ana[:,3]
        u_ana    = data_ana[:,2]
        p_ana    = data_ana[:,4]
        T_ana    = data_ana[:,5]*1.2027e-8/2.5
        
        data=read_output(-1)
        plt.plot(x_ana,rho_ana,color='k',label='analytical solution')
        plt.plot(data['x'],data['rho'],color='r',linestyle='dashed',label='SHARK')
        plt.xlabel("x")
        plt.ylabel("density [code units]")
        plt.legend()
        plt.show()
        plt.plot(x_ana,u_ana,color='k',label='analytical solution')
        plt.plot(data['x'],data['vx'],color='r',linestyle='dashed',label='SHARK')
        plt.xlabel("x")
        plt.ylabel("Velocity [code units]")
        plt.legend()
        plt.show()
        
    if(test=="DUSTYWAVE"):
        flags="SETUP=DUSTYWAVE NX="+str(options["RESOLUTION"])+" NY=1 NDUST=1 NGHOST=2 NDUSTPSCAL=0 OPENMP="+str(options["OPENMP"])+" DEBUG=0 SOLVER="+str(options["SOLVER"]) +" SOLVERDUST="+str(options["SOLVERDUST"])
        if(flag_change is not None):
            flags=flag_change
        print ('You are compiling with the options '+ flags )
        os.chdir(bin_dir)
        os.system("make clean && make "+flags)
        os.chdir(suite_dir+'/'+test)
        os.system('rm -rf output_*')

        #Wave with K = 1000
        os.system("export OMP_NUM_THREADS="+str(options["NUM_THREAD"])+";"+bin_dir+'/shark wave1000.nml')
        data_ana    = np.loadtxt(suite_dir+'/'+test+'/dustywave-K1000.dat')
        x_ana       = data_ana[:,0]
        vg_ana      = data_ana[:,1]
        vd_ana      = data_ana[:,2]
        rhog_ana    = data_ana[:,3]
        rhod_ana    = data_ana[:,4]
        data=read_output(-1)
        
        
        plt.plot(x_ana,vg_ana,color='k',label='analytical solution - Gas')
        plt.plot(data['x'],data['vx'],color='r',label='SHARK - Gas')
        plt.xlabel("x")
        plt.ylabel("Velocity gas [code units]")
        plt.ylim(-1e-4,1e-4)
        plt.legend()
        plt.show()    
        
        plt.plot(x_ana,vd_ana,color='k',label='analytical solution - Dust')
        plt.plot(data['x'],data['vdx'],color='b',linestyle='dashed',label='SHARK - Dust')
        plt.xlabel("x")
        plt.ylabel("Velocity dust [code units]")
        plt.ylim(-1e-4,1e-4)
        plt.legend()
        plt.show()        
        
        #Wave with K = 100
        os.system('rm -rf output_*')
        os.system("export OMP_NUM_THREADS="+str(options["NUM_THREAD"])+";"+bin_dir+'/shark wave100.nml')
        data_ana = np.loadtxt(suite_dir+'/'+test+'/dustywave-K100.dat')
        x_ana       = data_ana[:,0]
        vg_ana      = data_ana[:,1]
        vd_ana      = data_ana[:,2]
        rhog_ana    = data_ana[:,3]
        rhod_ana    = data_ana[:,4]
        data=read_output(-1)
        
        
        plt.plot(x_ana,vg_ana,color='k',label='analytical solution - Gas')
        plt.plot(data['x'],data['vx'],color='r',label='SHARK - Gas')
        plt.xlabel("x")
        plt.ylabel("Velocity gas [code units]")
        plt.ylim(-1e-4,1e-4)
        plt.legend()
        plt.show()    
        
        plt.plot(x_ana,vd_ana,color='k',label='analytical solution - Dust')
        plt.plot(data['x'],data['vdx'],color='b',linestyle='dashed',label='SHARK - Dust')
        plt.xlabel("x")
        plt.ylabel("Velocity dust [code units]")
        plt.ylim(-1e-4,1e-4)
        plt.legend()
        plt.show()        
        
        #Wave with K = 50
        os.system('rm -rf output_*')
        os.system("export OMP_NUM_THREADS="+str(options["NUM_THREAD"])+";"+bin_dir+'/shark wave50.nml')
        data_ana = np.loadtxt(suite_dir+'/'+test+'/dustywave-K50.dat')
        x_ana       = data_ana[:,0]
        vg_ana      = data_ana[:,1]
        vd_ana      = data_ana[:,2]
        rhog_ana    = data_ana[:,3]
        rhod_ana    = data_ana[:,4]
        data=read_output(-1)
        
        
        plt.plot(x_ana,vg_ana,color='k',label='analytical solution - Gas')
        plt.plot(data['x'],data['vx'],color='r',label='SHARK - Gas')
        plt.xlabel("x")
        plt.ylabel("Velocity gas [code units]")
        plt.ylim(-1e-4,1e-4)
        plt.legend()
        plt.show()    
        
        plt.plot(x_ana,vd_ana,color='k',label='analytical solution - Dust')
        plt.plot(data['x'],data['vdx'],color='b',linestyle='dashed',label='SHARK - Dust')
        plt.xlabel("x")
        plt.ylabel("Velocity dust [code units]")
        plt.ylim(-1e-4,1e-4)
        plt.legend()
        plt.show()        



    if (test=="DIFFUSION_SOLVER"): ###MHD_turb branch###

        flags="SETUP=diffusion NX=1024 MHD=1"
        if(flag_change is not None):
            flags=flag_change        
        print ('You are compiling with the options '+ flags )
        
        os.chdir(bin_dir)
        os.system("make clean && make "+flags)
        os.chdir(suite_dir+'/Diffusion')
        os.system('rm -rf output_*')
        os.system("export OMP_NUM_THREADS="+str(options["NUM_THREAD"])+";"+bin_dir+'/shark DIFFUSION.nml')
                
        
        
        data_var={}
        var='test'
        filelist = sorted(glob.glob("output*"))
        
        
        data=[]
        for i in range(1,len(filelist)+1,1):
            data.append(read_output(number=i))
        
        
        data = np.array(data)
        x=[]
        By=[]
        time=[]
        
        
        
        for i in range(0,len(data)):
            x.append(data[i]['x'][:])
            By.append(data[i]['By'][:])
            time.append(data[i]['infos']["time"])
        
        x=np.array(x)
        By=np.array(By)
        time=np.array(time)
        
        data_var[var,'x'] = x
        data_var[var,'By'] = By
        data_var[var,'time'] = time

        # Parameters
        
        x_c = 0.05
        u0=1
        
        #Initial condition for Barenblatt-Pattle solution 
        def CI(x):
            return np.maximum(0,u0*(1 - ((x-5)/x_c)**2 ))


        
        
        m = 2  # Value describing the level of non-linearity ): m = 1 --> dt(u) = dx(dx(u)). m = 2 --> dt(u) = dx(2udx(u))
        C = (u0*x_c/np.sqrt(6))**(2/3)
        t0 = C**3/(2*u0**3)
        
        
        # Barenblatt-Pattle solution
        def barenblatt_solution(x, t):
            return np.maximum(0,(2*t) ** (-1/3) *( C - 1/6 * (x-5)**2/(2*t)**(2/3) ))
        
        #Comparison
            from matplotlib.markers import MarkerStyle
                
        
        time = data_var[var,'time'][0::]
        x_plot = data_var[var,'x'][0][0:-1:2]
        By = data_var[var,'By'].squeeze()
        By = By[:,0:-1:2]
        
        a = CI(x_plot)
        
        #Plot with IC
        fig = plt.figure()
        plt.plot(x_plot,a,color='black')
        for t in range(0,len(time),1):
        
            plt.scatter(x_plot,By[t],label='t='+str(truncate(time[t],6)),alpha=0.5,s=40)
            u = barenblatt_solution(x_plot,t0+time[t])
            plt.plot(x_plot, u,color='black')
        plt.legend()
        plt.xlabel('x [unit code]')
        plt.ylabel('$B_\\mathrm{y}$ [unit code]')
        plt.legend()
        plt.grid(True)
        plt.figure(figsize=(10, 6))
        plt.show()
        
        #Second plot zoomed in
        fig = plt.figure()
        plt.plot(x_plot,a,color='black')
        for t in range(0,len(time),1):
        
            plt.scatter(x_plot,By[t],label='t='+str(truncate(time[t],6)),alpha=0.5,s=40)
            u = barenblatt_solution(x_plot,t0+time[t])
            plt.plot(x_plot, u,color='black')
        plt.legend()
        plt.ylim(0,0.1)
        plt.xlabel('x [unit code]')
        plt.ylabel('$B_\\mathrm{y}$ [unit code]')
        plt.legend()
        plt.grid(True)
        plt.figure(figsize=(10, 6))

    if (test=="DUSTY_MHD_TURB_CV"):  ###MHD_turb branch###

        for NX in ["1024","2048"]:

            flags="SETUP=dustyTurb NX="+NX+" MHD=1 TURB=1 NDUST=1 SOLVER=1 SOLVERDUST=2 SOLVERB=2 OPENMP=1"
            if(flag_change is not None):
                flags=flag_change        
            print ('You are compiling with the options '+ flags )
            
            os.chdir(bin_dir)
            os.system("make clean && make "+flags)
            os.chdir(suite_dir+'/Dusty_MHD_turb'+'/NX'+NX)
            os.system('rm -rf output_*')
            os.system("export OMP_NUM_THREADS="+str(options["NUM_THREAD"])+";"+bin_dir+'/shark DUSTY_TURB_CV_TEST.nml')
                    
        
        
        data_var={}
        for var in ["1024","2048"]:
            NX = var
            os.chdir(suite_dir+'/Dusty_MHD_turb'+'/NX'+NX)
           
            filelist = sorted(glob.glob("output*"))
            
            data=[]
            for i in range(1,len(filelist)+1,1):
                data.append(read_output(number=i))
            
            
            data = np.array(data)
            x=[]
            time=[]
            rho=[]
            rhod=[]
                
                
            
            for i in range(0,len(data)):
                x.append(data[i]['x'][:])
                time.append(data[i]['infos']["time"])
                rho.append(data[i]['rho'][:])
                rhod.append(data[i]['rhod'][:])
                
            x=np.array(x)
            time=np.array(time)
            rho=np.array(rho)
            rhod=np.array(rhod)
            
            data_var[var,'x'] = x
            data_var[var,'time'] = time
            data_var[var,'rho'] = rho
            data_var[var,'rhod'] = rhod
            
        e_el_stat     = 4.8e-10      # Electron charge /!\ in statcoulomb here.
        m_el          = 9.109e-28    # Electron mass in grams
        clight        = 3e10         # Speed of light
        mH            = 1.67e-24     # Mass of an hydrogen atom
        kB            = 1.38e-16     # Boltzmann constant
        Grav          = 6.67e-8      # Gravity constant
        au            = 1.5e13       # Astronomical unit
        pc            = 3e18         # Parsec
        Msun          = 2e33         # Solar mass
        pi            = 3.141592653589793238462643383279e0  # Pi
        gamma           = 5/3
        mu_gas      = 2.31e0
        rho_gr       = 2.3
        
        nh=1e6
        rho_0=mu_gas*mH*nh
        
        T=10
        cs_0= np.sqrt(gamma*kB*T/(mu_gas*mH))
        L = cs_0/np.sqrt(Grav*rho_0)
        beta=1        
        ca=cs_0/np.sqrt(beta)
        crossing_time = L/ca
        fig = plt.figure()
        m=0
        color_array=['black','red']
        for var in ["1024","2048"]:
        
        
            label = 'NX'+var
        
            time=data_var[var,'time']/crossing_time
            rhod_max = np.log10(np.max((data_var[var,'rhod']/(0.01*rho_0)).squeeze(),1))
            rho_max = np.log10(np.max((data_var[var,'rho']/(rho_0)).squeeze(),1))
        
            plt.plot(time,rhod_max,label=label,alpha=0.8,color=color_array[m])
            plt.plot(time,rho_max,alpha=0.8,linestyle="dotted",color=color_array[m])
            m+=1
        plt.yscale('linear')
        plt.xlabel('Time [Alfven crossing-time]')
        plt.ylabel("$\\mathrm{Log}(\\rho_\\mathrm{d,max}/\\rho_\\mathrm{d,0})$")        
        plt.legend()
        plt.show()

    if (test=="DUSTY_MHD_TURB_BETA"):  ###MHD_turb branch###

        NX='2048'
        flags="SETUP=dustyTurb NX="+NX+" MHD=1 TURB=1 NDUST=1 SOLVER=1 SOLVERDUST=2 SOLVERB=2 OPENMP=1"
        if(flag_change is not None):
            flags=flag_change        
        print ('You are compiling with the options '+ flags )
        for beta in ['1e-1','1']:            
            os.chdir(bin_dir)
            os.system("make clean && make "+flags)
            os.chdir(suite_dir+'/Dusty_MHD_turb'+'/beta'+beta)
            os.system('rm -rf output_*')
            os.system("export OMP_NUM_THREADS="+str(options["NUM_THREAD"])+";"+bin_dir+'/shark DUSTY_TURB_beta'+beta+'.nml')
                    
    
        
        data_var={}
        for var in ['1e-1','1']:
            
            os.chdir(suite_dir+'/Dusty_MHD_turb'+'/beta'+beta)
           
            filelist = sorted(glob.glob("output*"))
            
            data=[]
            for i in range(1,len(filelist)+1,1):
                data.append(read_output(number=i))
            
            
            data = np.array(data)
            x=[]
            time=[]
            rho=[]
            rhod=[]
                
                
            
            for i in range(0,len(data)):
                x.append(data[i]['x'][:])
                time.append(data[i]['infos']["time"])
                rho.append(data[i]['rho'][:])
                rhod.append(data[i]['rhod'][:])
                
            x=np.array(x)
            time=np.array(time)
            rho=np.array(rho)
            rhod=np.array(rhod)
            
            data_var[var,'x'] = x
            data_var[var,'time'] = time
            data_var[var,'rho'] = rho
            data_var[var,'rhod'] = rhod
            
        e_el_stat     = 4.8e-10      # Electron charge /!\ in statcoulomb here.
        m_el          = 9.109e-28    # Electron mass in grams
        clight        = 3e10         # Speed of light
        mH            = 1.67e-24     # Mass of an hydrogen atom
        kB            = 1.38e-16     # Boltzmann constant
        Grav          = 6.67e-8      # Gravity constant
        au            = 1.5e13       # Astronomical unit
        pc            = 3e18         # Parsec
        Msun          = 2e33         # Solar mass
        pi            = 3.141592653589793238462643383279e0  # Pi
        gamma           = 5/3
        mu_gas      = 2.31e0
        rho_gr       = 2.3
        
        nh=1e6
        rho_0=mu_gas*mH*nh
        
        T=10
        cs_0= np.sqrt(gamma*kB*T/(mu_gas*mH))
        L = cs_0/np.sqrt(Grav*rho_0)
        beta=np.array([0.1,1.0])        
        ca=cs_0/np.sqrt(beta)
        fig = plt.figure()
        m=0
        color_array=['black','red']
        for var in ['1e-1','1']:
        
            crossing_time = L/ca[m]

            label = '$\\beta$'+var        
            time=data_var[var,'time']/crossing_time
            rhod_max = np.log10(np.max((data_var[var,'rhod']/(0.01*rho_0)).squeeze(),1))
            rho_max = np.log10(np.max((data_var[var,'rho']/(rho_0)).squeeze(),1))
        
            plt.plot(time,rhod_max,label=label,alpha=0.8,color=color_array[m])
            plt.plot(time,rho_max,alpha=0.8,linestyle="dotted",color=color_array[m])
            m+=1
        plt.yscale('linear')
        plt.xlabel('Time [Alfven crossing-time]')
        plt.ylabel("$\\mathrm{Log}(\\rho_\\mathrm{d,max}/\\rho_\\mathrm{d,0})$")        
        plt.legend()
        plt.show()

# %% [markdown]
# # Tests

# %% [markdown]
# ## Test 1 : Sod-tube

# %% [markdown]
# This is the first test to be ran, this is a simple 1D simulation of a propagating shock. This test has an analytical solution and serves as a validation of the gas.

# %%
run_test(test='Sod-tube')
# Out:
# You are compiling with the options SETUP=SOD NX=2048 NY=1 NGHOST=2 OPENMP=1 DEBUG=0 SOLVER=2
# rm -f *.o *. *__genmod.f90 *mod shark
# for file in precision.o phys_const.o hydro_commons.o setup_commons.o gravity_commons.o ionisation_commons.o random.o newton_raphson.o  commons.o parameters.o units.o boundary_types.o slope_limiters.o allocate_init.o ionisation_utils.o functions_NR.o ionisation.o grid.o solvers.o eos.o setup.o courant.o godunov.o boundaries.o write_output.o read_output.o source_terms.o force_kicks.o  gravity_utils.o; do unset MAKELEVEL ; /Library/Developer/CommandLineTools/usr/bin/make $file; done
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/precision.f90 -o precision.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/phys_const.f90 -o phys_const.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/hydro/hydro_commons.f90 -o hydro_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/setups/SOD/setup_commons.f90 -o setup_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/gravity/gravity_commons.f90 -o gravity_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/chemistry/ionisation_commons.f90 -o ionisation_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/random.f90 -o random.o
# ../src/commons/random.f90:165:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   165 |           SeedArray( I, 1 ) = OutSeed( 1 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# ../src/commons/random.f90:166:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   166 |           SeedArray( I, 2 ) = OutSeed( 2 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# ../src/commons/random.f90:167:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   167 |           SeedArray( I, 3 ) = OutSeed( 3 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# ../src/commons/random.f90:168:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   168 |           SeedArray( I, 4 ) = OutSeed( 4 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/newton_raphson.f90 -o newton_raphson.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/commons.f90 -o commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/parameters.f90 -o parameters.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/setups/SOD/units.f90 -o units.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/grid/boundary_types.f90 -o boundary_types.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/slope_limiters.f90 -o slope_limiters.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/allocate_init.f90 -o allocate_init.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/chemistry/ionisation_utils.f90 -o ionisation_utils.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/chemistry/functions_NR.f90 -o functions_NR.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/chemistry/ionisation.f90 -o ionisation.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/grid/grid.f90 -o grid.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/solvers.f90 -o solvers.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/setups/SOD/eos.f90 -o eos.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/setups/SOD/setup.f90 -o setup.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/courant.f90 -o courant.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/godunov.f90 -o godunov.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/setups/SOD/boundaries.f90 -o boundaries.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/write_output.f90 -o write_output.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/read_output.f90 -o read_output.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/source_terms.f90 -o source_terms.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/force_kicks.f90 -o force_kicks.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/gravity/gravity_utils.f90 -o gravity_utils.o
# /Library/Developer/CommandLineTools/usr/bin/make shark
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/solve.f90 -o solve.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/read_params.f90 -o read_params.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=0 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0  -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/shark.f90 -o shark.o
# gfortran -fopenmp  precision.o phys_const.o hydro_commons.o setup_commons.o gravity_commons.o ionisation_commons.o random.o newton_raphson.o  commons.o parameters.o units.o boundary_types.o slope_limiters.o allocate_init.o ionisation_utils.o functions_NR.o ionisation.o grid.o solvers.o eos.o setup.o courant.o godunov.o boundaries.o write_output.o read_output.o source_terms.o force_kicks.o  gravity_utils.o solve.o read_params.o shark.o -o ./shark
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#    ssss hh   hh     aaa      rrrrrr   kk   kk
#   sss   hh   hh    aa aa     rr  rrr  kk  kk
#    sss  hhhhhhh   aaaaaaa    rrrrr    kk kk
#     sss hh   hh  aaa    aaa  rr  rr   kk  kk
#   ssss  hh   hh aaa      aaa rr    rr kk   kk
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!000!!!!!!!!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!00!!000!!!!!!!!D!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!000!!!!!!!D!!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!000!!!!!!!!!D!!!!!!D!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!00!!!!!!!!!!!D!!!!!!D!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!000!!!!!!!!!!!!D!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!00000000!!!!!!!!DDDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!Ugo Lebreuilly            !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!CEA SACLAY                !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!ugo.lebreuilly@cea.fr     !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  ------------------------------------------------------------
#                                    /
#                                 ,::|
#                               /::::|
#                              ,:::::\                                      _..
#           ____........-------,..:::::                                   -  /
#   _.--"""". . . .      .   .  .  .  ""`-._                            -  .;
#  <. - :::::O......  ...   . . .. . .  .  .""--._                  ,- . .;
#   `-._  ` `":`:`:`::||||:::::::::::::::::.:. .  ""--._ ,/|     ,- .  .;
#       """_---       // :::.. ````:`:`::::::::::.:.:.:. .`-`._- .   .;
#           ""--.__      (       \               ` ``:`:``:::: .   .;
#                  "\""--.:-.     `.                             .:
#                    \  /    `-._   `.""-----.,-..::(--"".\""`.  `:\
#                     `/         `-._ \          `-:\          `. `:\
#                                     ""            "            `-._)
#   You are using            8  threads
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Namelist reading : sod.nml
#  Grid namelist reading  !
#  Dynamics activated
#  Gravity namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Gravity namelist reading  !
#  Gravity is used
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Ionisation namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  ionisation_params namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Setup namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Setup namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Namelist reading ok !
#  ########################################################################################################################################
#  ########################################################################################################################################
#         2048  active cells were prepared.
#  Are the indices in order ?
#  irho =           1
#  ivx   =           2
#  ivy  =           3
#  ivz  =           4
#  iP   =           5
#  Nvar =           5
#  Number of cells        =         2052
#  Number of active cells =         2048
#  You are using a linear cartesian grid.
#  Outputing data
#  Total mass is   1156.0000000000000
#  Total momentum is   0.0000000000000000
#  Total energy is   2826.0000000000005
#  time =  0.17797462167853825       tend =   0.24500000000000000
#  Outputing data
#  Total mass is   1154.2499999999993
#  Total momentum is   328.04282267788153
#  Total energy is   2821.5000000000050
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :         1000  Output            2
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is       0.17797462167853825
#  timestep is    1.7814218452044569E-004
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.3260340632603409      (%) ,   2.6000001234933734E-002  seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Courant                     0.97323600973236013      (%) ,   4.0000001899898052E-003  seconds
#  Predictor step               31.873479318734795      (%) ,  0.13100000622216612       seconds
#  Corrector step               37.226277372262771      (%) ,  0.15300000726711005       seconds
#  Source terms                 23.600973236009732      (%) ,   9.7000004607252777E-002  seconds
#  Dust                         0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Force kick + setup action    0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Running time is   0.41100001952145249       seconds
#  The simulation is over. Enjoy your results.
#  Elapsed real time   0.584999979
# Reading output 00003
# nvar =  5
# ndust =  0
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  0
# GEOM =  0
# TURB =  0
# GRIDSPACE =  0
# time =  0.245094188353975
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  0
# call_electric_field =  0

# %% [markdown]
# # Test 2 : Dustywave

# %% [markdown]
# Here we test the propagation of a gas & dust sound-wave or DUSTYWAVE. The drag between the gas and the dust generates a damping of the wave. The stronger the coupling is, the weaker the damping. Here we test 3 values for the drag coefficient K that controls the value of the stopping time : 50 (weak coupling), 100 (intermediate coupling) and 1000 (strong coupling). This test is 1D, but we compile the code with one dust species so we validate both the gas and the dust dynamics.

# %%
run_test(test='DUSTYWAVE')
# Out:
# You are compiling with the options SETUP=DUSTYWAVE NX=2048 NY=1 NDUST=1 NGHOST=2 NDUSTPSCAL=0 OPENMP=1 DEBUG=0 SOLVER=2 SOLVERDUST=0
# rm -f *.o *. *__genmod.f90 *mod shark
# for file in precision.o phys_const.o hydro_commons.o setup_commons.o gravity_commons.o ionisation_commons.o random.o newton_raphson.o  dust_commons.o  commons.o parameters.o units.o boundary_types.o slope_limiters.o allocate_init.o ionisation_utils.o functions_NR.o ionisation.o grid.o solvers.o eos.o setup.o courant.o godunov.o boundaries.o write_output.o read_output.o source_terms.o force_kicks.o  dust_init.o dust_drag.o dust_growth.o gravity_utils.o; do unset MAKELEVEL ; /Library/Developer/CommandLineTools/usr/bin/make $file; done
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/commons/precision.f90 -o precision.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/commons/phys_const.f90 -o phys_const.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/hydro/hydro_commons.f90 -o hydro_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/setups/DUSTYWAVE/setup_commons.f90 -o setup_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/gravity/gravity_commons.f90 -o gravity_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/chemistry/ionisation_commons.f90 -o ionisation_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/commons/random.f90 -o random.o
# ../src/commons/random.f90:165:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   165 |           SeedArray( I, 1 ) = OutSeed( 1 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# ../src/commons/random.f90:166:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   166 |           SeedArray( I, 2 ) = OutSeed( 2 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# ../src/commons/random.f90:167:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   167 |           SeedArray( I, 3 ) = OutSeed( 3 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# ../src/commons/random.f90:168:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   168 |           SeedArray( I, 4 ) = OutSeed( 4 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/commons/newton_raphson.f90 -o newton_raphson.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/dust/dust_commons.f90 -o dust_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/commons/commons.f90 -o commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/commons/parameters.f90 -o parameters.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/setups/DUSTYWAVE/units.f90 -o units.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/grid/boundary_types.f90 -o boundary_types.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/solver/slope_limiters.f90 -o slope_limiters.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/commons/allocate_init.f90 -o allocate_init.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/chemistry/ionisation_utils.f90 -o ionisation_utils.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/chemistry/functions_NR.f90 -o functions_NR.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/chemistry/ionisation.f90 -o ionisation.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/grid/grid.f90 -o grid.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/solver/solvers.f90 -o solvers.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/setups/DUSTYWAVE/eos.f90 -o eos.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/setups/DUSTYWAVE/setup.f90 -o setup.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/solver/courant.f90 -o courant.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/solver/godunov.f90 -o godunov.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/setups/DUSTYWAVE/boundaries.f90 -o boundaries.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/commons/write_output.f90 -o write_output.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/commons/read_output.f90 -o read_output.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/solver/source_terms.f90 -o source_terms.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/solver/force_kicks.f90 -o force_kicks.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/dust/dust_init.f90 -o dust_init.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/dust/dust_drag.f90 -o dust_drag.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/dust/dust_growth.f90 -o dust_growth.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/gravity/gravity_utils.f90 -o gravity_utils.o
# /Library/Developer/CommandLineTools/usr/bin/make shark
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/solver/solve.f90 -o solve.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/commons/read_params.f90 -o read_params.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1 -DGRIDSPACE=0  -DGEOM=0 -DMHD=0 -DOPENMP=1 -DSOLVER=2 -DSOLVERDUST=0 -DSOLVERB=1  -DNGHOST=2 -DTURB=0 -DGRAVITY=0 -DNDUSTPSCAL=0 -DDUST_PRESSURE=0  -c ../src/shark.f90 -o shark.o
# gfortran -fopenmp  precision.o phys_const.o hydro_commons.o setup_commons.o gravity_commons.o ionisation_commons.o random.o newton_raphson.o  dust_commons.o  commons.o parameters.o units.o boundary_types.o slope_limiters.o allocate_init.o ionisation_utils.o functions_NR.o ionisation.o grid.o solvers.o eos.o setup.o courant.o godunov.o boundaries.o write_output.o read_output.o source_terms.o force_kicks.o  dust_init.o dust_drag.o dust_growth.o gravity_utils.o solve.o read_params.o shark.o -o ./shark
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#    ssss hh   hh     aaa      rrrrrr   kk   kk
#   sss   hh   hh    aa aa     rr  rrr  kk  kk
#    sss  hhhhhhh   aaaaaaa    rrrrr    kk kk
#     sss hh   hh  aaa    aaa  rr  rr   kk  kk
#   ssss  hh   hh aaa      aaa rr    rr kk   kk
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!000!!!!!!!!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!00!!000!!!!!!!!D!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!000!!!!!!!D!!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!000!!!!!!!!!D!!!!!!D!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!00!!!!!!!!!!!D!!!!!!D!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!000!!!!!!!!!!!!D!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!00000000!!!!!!!!DDDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!Ugo Lebreuilly            !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!CEA SACLAY                !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!ugo.lebreuilly@cea.fr     !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  ------------------------------------------------------------
#                                    /
#                                 ,::|
#                               /::::|
#                              ,:::::\                                      _..
#           ____........-------,..:::::                                   -  /
#   _.--"""". . . .      .   .  .  .  ""`-._                            -  .;
#  <. - :::::O......  ...   . . .. . .  .  .""--._                  ,- . .;
#   `-._  ` `":`:`:`::||||:::::::::::::::::.:. .  ""--._ ,/|     ,- .  .;
#       """_---       // :::.. ````:`:`::::::::::.:.:.:. .`-`._- .   .;
#           ""--.__      (       \               ` ``:`:``:::: .   .;
#                  "\""--.:-.     `.                             .:
#                    \  /    `-._   `.""-----.,-..::(--"".\""`.  `:\
#                     `/         `-._ \          `-:\          `. `:\
#                                     ""            "            `-._)
#   You are using            8  threads
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Namelist reading : wave1000.nml
#  Grid namelist reading  !
#  Dynamics activated
#  Dust namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Dust namelist reading  !
#   Minimal grain size possible :    9.9999999999999995E-008
#   Maximal grain size possible :    1.0000000000000000E-002
#   Grain density               :   2.7000000000000002
#   Dust-to-gas ratio           :   1.0000000000000000E-002
#   Ice mantle                  :   8.7000000000000003E-007
#   MRN dust distribution
#   MRN index             :    3.5000000000000000
#   Minimal grain size    :    4.9999999999999998E-007
#   Maximal grain size    :    2.5000000000000001E-005
#  Growth is deactivated
#  Fragmentation is deactivated
#  charging is not computed
#  physical kernel
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Gravity namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Gravity namelist reading  !
#  Gravity is used
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Ionisation namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  ionisation_params namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Setup namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Setup namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Namelist reading ok !
#  ########################################################################################################################################
#  ########################################################################################################################################
#         2048  active cells were prepared.
#  Are the indices in order ?
#  irho =           1
#  ivx   =           2
#  ivy  =           3
#  ivz  =           4
#  iP   =           5
#  idust   =           1 irhod =            6  ivdx =            7  ivdy =            8  ivdz =            9
#  Nvar =           9
#  Number of cells        =         2052
#  Number of active cells =         2048
#  You are using a linear cartesian grid.
#  Initial dust distribution, size :
#    3.2492776601683792E-005
#  Initial dust distribution, epsilon :
#    1.0000000000000002E-002
#  Initial dust distribution, mass :
#    3.5764518822731662E-013
#  Outputing data
#  Total mass is   2052.0000000000000
#  Total momentum is   1.0239999999961257E-005
#  Total energy is   3077.9998512200118
#  time =   1.9525691960199312       tend =    4.5000000000000000
#  Outputing data
#  Total mass is   2051.9996189730841
#  Total momentum is  -1.7973754310555664E-004
#  Total energy is   3077.9988980391613
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :         5000  Output            2
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        1.9525691960199312
#  timestep is    3.9059125293815217E-004
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         11.866818442096164      (%) ,  0.41700001980643719       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      6.4029595910590809      (%) ,  0.22500001068692654       seconds
#  Courant                     0.73989755274460489      (%) ,   2.6000001234933734E-002  seconds
#  Predictor step               18.070574842564952      (%) ,  0.63500003004446626       seconds
#  Corrector step               24.672737614275626      (%) ,  0.86700004083104432       seconds
#  Source terms                 15.509391009454218      (%) ,  0.54500002588611096       seconds
#  Dust                         22.737620947805361      (%) ,  0.79900003795046359       seconds
#  Force kick + setup action    0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Running time is    3.5140001664403826       seconds
#  time =   3.9055282112194991       tend =    4.5000000000000000
#  Outputing data
#  Total mass is   2052.0005492453670
#  Total momentum is   2.8485397421799632E-004
#  Total energy is   3078.0012237198025
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        10000  Output            3
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        3.9055282112194991
#  timestep is    3.9059804186949981E-004
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         11.639226915593404      (%) ,  0.81300003861542791       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      6.2562634220348317      (%) ,  0.43700002075638622       seconds
#  Courant                     0.88761632074636065      (%) ,   6.2000002944841981E-002  seconds
#  Predictor step               18.339298496334770      (%) ,   1.2810000607278198       seconds
#  Corrector step               24.380816030984768      (%) ,   1.7030000805389136       seconds
#  Source terms                 15.676449535762336      (%) ,   1.0950000520097092       seconds
#  Dust                         22.820329278543529      (%) ,   1.5940000757109374       seconds
#  Force kick + setup action    0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Running time is    6.9850003313040361       seconds
#  The simulation is over. Enjoy your results.
#  Elapsed real time    8.06200027
# Reading output 00004
# nvar =  9
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  0
# GEOM =  0
# TURB =  0
# GRIDSPACE =  0
# time =  4.5000083093549
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  0
# call_electric_field =  0
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#    ssss hh   hh     aaa      rrrrrr   kk   kk
#   sss   hh   hh    aa aa     rr  rrr  kk  kk
#    sss  hhhhhhh   aaaaaaa    rrrrr    kk kk
#     sss hh   hh  aaa    aaa  rr  rr   kk  kk
#   ssss  hh   hh aaa      aaa rr    rr kk   kk
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!000!!!!!!!!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!00!!000!!!!!!!!D!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!000!!!!!!!D!!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!000!!!!!!!!!D!!!!!!D!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!00!!!!!!!!!!!D!!!!!!D!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!000!!!!!!!!!!!!D!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!00000000!!!!!!!!DDDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!Ugo Lebreuilly            !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!CEA SACLAY                !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!ugo.lebreuilly@cea.fr     !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  ------------------------------------------------------------
#                                    /
#                                 ,::|
#                               /::::|
#                              ,:::::\                                      _..
#           ____........-------,..:::::                                   -  /
#   _.--"""". . . .      .   .  .  .  ""`-._                            -  .;
#  <. - :::::O......  ...   . . .. . .  .  .""--._                  ,- . .;
#   `-._  ` `":`:`:`::||||:::::::::::::::::.:. .  ""--._ ,/|     ,- .  .;
#       """_---       // :::.. ````:`:`::::::::::.:.:.:. .`-`._- .   .;
#           ""--.__      (       \               ` ``:`:``:::: .   .;
#                  "\""--.:-.     `.                             .:
#                    \  /    `-._   `.""-----.,-..::(--"".\""`.  `:\
#                     `/         `-._ \          `-:\          `. `:\
#                                     ""            "            `-._)
#   You are using            8  threads
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Namelist reading : wave100.nml
#  Grid namelist reading  !
#  Dynamics activated
#  Dust namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Dust namelist reading  !
#   Minimal grain size possible :    9.9999999999999995E-008
#   Maximal grain size possible :    1.0000000000000000E-002
#   Grain density               :   2.7000000000000002
#   Dust-to-gas ratio           :   1.0000000000000000E-002
#   Ice mantle                  :   8.7000000000000003E-007
#   MRN dust distribution
#   MRN index             :    3.5000000000000000
#   Minimal grain size    :    4.9999999999999998E-007
#   Maximal grain size    :    2.5000000000000001E-005
#  Growth is deactivated
#  Fragmentation is deactivated
#  charging is not computed
#  physical kernel
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Gravity namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Gravity namelist reading  !
#  Gravity is used
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Ionisation namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  ionisation_params namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Setup namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Setup namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Namelist reading ok !
#  ########################################################################################################################################
#  ########################################################################################################################################
#         2048  active cells were prepared.
#  Are the indices in order ?
#  irho =           1
#  ivx   =           2
#  ivy  =           3
#  ivz  =           4
#  iP   =           5
#  idust   =           1 irhod =            6  ivdx =            7  ivdy =            8  ivdz =            9
#  Nvar =           9
#  Number of cells        =         2052
#  Number of active cells =         2048
#  You are using a linear cartesian grid.
#  Initial dust distribution, size :
#    3.2492776601683792E-005
#  Initial dust distribution, epsilon :
#    1.0000000000000002E-002
#  Initial dust distribution, mass :
#    3.5764518822731662E-013
#  Outputing data
#  Total mass is   2052.0000000000000
#  Total momentum is   1.0239999999961257E-005
#  Total energy is   3077.9998512200118
#  time =   1.9525391322056658       tend =    4.5000000000000000
#  Outputing data
#  Total mass is   2052.0001179699761
#  Total momentum is   1.2821342427994431E-004
#  Total energy is   3078.0001455313491
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :         5000  Output            2
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        1.9525391322056658
#  timestep is    3.9058594528743615E-004
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         16.464339908952962      (%) ,  0.43400002061389387       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      7.9666160849772378      (%) ,  0.21000000997446477       seconds
#  Courant                      1.1380880121396053      (%) ,   3.0000001424923539E-002  seconds
#  Predictor step               23.520485584218513      (%) ,  0.62000002944841981       seconds
#  Corrector step               30.842185128983306      (%) ,  0.81300003861542791       seconds
#  Source terms                 20.030349013657055      (%) ,  0.52800002507865429       seconds
#  Dust                         3.7936267071320182E-002 (%) ,   1.0000000474974513E-003  seconds
#  Force kick + setup action    0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Running time is    2.6360001252032816       seconds
#  time =   3.9054688626498462       tend =    4.5000000000000000
#  Outputing data
#  Total mass is   2052.0002239103869
#  Total momentum is   2.3416289028808037E-004
#  Total energy is   3078.0004103823685
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        10000  Output            3
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        3.9054688626498462
#  timestep is    3.9058594661543777E-004
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         15.474839197881195      (%) ,  0.81800003885291517       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      8.3238743851683683      (%) ,  0.44000002089887857       seconds
#  Courant                      1.0594021944759744      (%) ,   5.6000002659857273E-002  seconds
#  Predictor step               23.193340900491865      (%) ,   1.2260000582318753       seconds
#  Corrector step               31.422625804010597      (%) ,   1.6610000788932666       seconds
#  Source terms                 20.506999621642073      (%) ,   1.0840000514872372       seconds
#  Dust                         1.8917896329928113E-002 (%) ,   1.0000000474974513E-003  seconds
#  Force kick + setup action    0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Running time is    5.2860002510715276       seconds
#  The simulation is over. Enjoy your results.
#  Elapsed real time    6.11499977
# Reading output 00004
# nvar =  9
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  0
# GEOM =  0
# TURB =  0
# GRIDSPACE =  0
# time =  4.50033126027311
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  0
# call_electric_field =  0
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#    ssss hh   hh     aaa      rrrrrr   kk   kk
#   sss   hh   hh    aa aa     rr  rrr  kk  kk
#    sss  hhhhhhh   aaaaaaa    rrrrr    kk kk
#     sss hh   hh  aaa    aaa  rr  rr   kk  kk
#   ssss  hh   hh aaa      aaa rr    rr kk   kk
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!000!!!!!!!!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!00!!000!!!!!!!!D!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!000!!!!!!!D!!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!000!!!!!!!!!D!!!!!!D!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!00!!!!!!!!!!!D!!!!!!D!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!000!!!!!!!!!!!!D!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!00000000!!!!!!!!DDDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!Ugo Lebreuilly            !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!CEA SACLAY                !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!ugo.lebreuilly@cea.fr     !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  ------------------------------------------------------------
#                                    /
#                                 ,::|
#                               /::::|
#                              ,:::::\                                      _..
#           ____........-------,..:::::                                   -  /
#   _.--"""". . . .      .   .  .  .  ""`-._                            -  .;
#  <. - :::::O......  ...   . . .. . .  .  .""--._                  ,- . .;
#   `-._  ` `":`:`:`::||||:::::::::::::::::.:. .  ""--._ ,/|     ,- .  .;
#       """_---       // :::.. ````:`:`::::::::::.:.:.:. .`-`._- .   .;
#           ""--.__      (       \               ` ``:`:``:::: .   .;
#                  "\""--.:-.     `.                             .:
#                    \  /    `-._   `.""-----.,-..::(--"".\""`.  `:\
#                     `/         `-._ \          `-:\          `. `:\
#                                     ""            "            `-._)
#   You are using            8  threads
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Namelist reading : wave50.nml
#  Grid namelist reading  !
#  Dynamics activated
#  Dust namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Dust namelist reading  !
#   Minimal grain size possible :    9.9999999999999995E-008
#   Maximal grain size possible :    1.0000000000000000E-002
#   Grain density               :   2.7000000000000002
#   Dust-to-gas ratio           :   1.0000000000000000E-002
#   Ice mantle                  :   8.7000000000000003E-007
#   MRN dust distribution
#   MRN index             :    3.5000000000000000
#   Minimal grain size    :    4.9999999999999998E-007
#   Maximal grain size    :    2.5000000000000001E-005
#  Growth is deactivated
#  Fragmentation is deactivated
#  charging is not computed
#  physical kernel
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Gravity namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Gravity namelist reading  !
#  Gravity is used
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Ionisation namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  ionisation_params namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Setup namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Setup namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Namelist reading ok !
#  ########################################################################################################################################
#  ########################################################################################################################################
#         2048  active cells were prepared.
#  Are the indices in order ?
#  irho =           1
#  ivx   =           2
#  ivy  =           3
#  ivz  =           4
#  iP   =           5
#  idust   =           1 irhod =            6  ivdx =            7  ivdy =            8  ivdz =            9
#  Nvar =           9
#  Number of cells        =         2052
#  Number of active cells =         2048
#  You are using a linear cartesian grid.
#  Initial dust distribution, size :
#    3.2492776601683792E-005
#  Initial dust distribution, epsilon :
#    1.0000000000000002E-002
#  Initial dust distribution, mass :
#    3.5764518822731662E-013
#  Outputing data
#  Total mass is   2052.0000000000000
#  Total momentum is   1.0239999999961257E-005
#  Total energy is   3077.9998512200118
#  time =   1.9525828610898774       tend =    4.5000000000000000
#  Outputing data
#  Total mass is   2051.9996846295016
#  Total momentum is  -1.4016236630529739E-004
#  Total energy is   3077.9990621801926
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :         5000  Output            2
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        1.9525828610898774
#  timestep is    3.9059676601209669E-004
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         9.9328074788197487      (%) ,  0.34000001614913344       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      6.5147531405200114      (%) ,  0.22300001059193164       seconds
#  Courant                     0.90563832895121243      (%) ,   3.1000001472420990E-002  seconds
#  Predictor step               19.719544259421561      (%) ,  0.67500003206077963       seconds
#  Corrector step               23.049956178790534      (%) ,  0.78900003747548908       seconds
#  Source terms                 15.892491966111599      (%) ,  0.54400002583861351       seconds
#  Dust                         23.984808647385332      (%) ,  0.82100003899540752       seconds
#  Force kick + setup action    0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Running time is    3.4230001625837758       seconds
#  time =   3.9055811007297683       tend =    4.5000000000000000
#  Outputing data
#  Total mass is   2052.0003809176033
#  Total momentum is   2.0049145536318717E-004
#  Total energy is   3078.0008029004039
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        10000  Output            3
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        3.9055811007297683
#  timestep is    3.9060623703136024E-004
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         10.466988727858293      (%) ,  0.71500003396067768       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      6.3241106719367588      (%) ,  0.43200002051889896       seconds
#  Courant                      1.0686575903967208      (%) ,   7.3000003467313945E-002  seconds
#  Predictor step               18.840579710144929      (%) ,   1.2870000611292198       seconds
#  Corrector step               23.920363050797832      (%) ,   1.6340000776108354       seconds
#  Source terms                 15.590689503732982      (%) ,   1.0650000505847856       seconds
#  Dust                         23.788610745132484      (%) ,   1.6250000771833584       seconds
#  Force kick + setup action    0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Running time is    6.8310003244550899       seconds
#  The simulation is over. Enjoy your results.
#  Elapsed real time    7.90000010
# Reading output 00004
# nvar =  9
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  0
# GEOM =  0
# TURB =  0
# GRIDSPACE =  0
# time =  4.50007778132959
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  0
# call_electric_field =  0

# %% [markdown]
# # Test 3: Diffusion solver

# %% [markdown]
# This only tests the diffusion solver in the setup/diffusion solver. Does not provide mich information but make sure it's still working.

# %%
run_test(test="DIFFUSION_SOLVER")

# %% [markdown]
# # Test 4: CV test dusty non ideal MHD

# %% [markdown]
# Here, we run a 1D simulation within the dustyTurb setup with non ideal MHD, a single dust grain, no electrons, and turbulence.
# The plots needs to be compared to Fig. D1 of Vallucci-Goy +25

# %%
run_test(test="DUSTY_MHD_TURB_CV")

# %% [markdown]
# # Test 5: beta test dusty non ideal MHD

# %% [markdown]
# Here, we run a 1D simulation within the dustyTurb setup with non ideal MHD, a single dust grain, no electrons, and turbulence.
# The plots needs to be compared to Fig. 4 of Vallucci-Goy +25 (But keep in mind that NX=4096 cells were used in the paper)

# %%
run_test(test="DUSTY_MHD_TURB_BETA")
# Out:
# You are compiling with the options SETUP=dustyTurb NX=2048 MHD=1 TURB=1 NDUST=1 SOLVER=1 SOLVERDUST=2 SOLVERB=2 OPENMP=1
# rm -f *.o *. *__genmod.f90 *mod shark
# for file in precision.o phys_const.o hydro_commons.o setup_commons.o gravity_commons.o ionisation_commons.o random.o newton_raphson.o  dust_commons.o  turb_commons.o commons.o parameters.o units.o boundary_types.o slope_limiters.o allocate_init.o ionisation_utils.o functions_NR.o ionisation.o grid.o solvers.o eos.o setup.o courant.o godunov.o boundaries.o write_output.o read_output.o source_terms.o force_kicks.o  dust_init.o dust_drag.o dust_growth.o turb_utils.o turb.o gravity_utils.o; do unset MAKELEVEL ; /Library/Developer/CommandLineTools/usr/bin/make $file; done
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/precision.f90 -o precision.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/phys_const.f90 -o phys_const.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/hydro/hydro_commons.f90 -o hydro_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/setups/dustyTurb/setup_commons.f90 -o setup_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/gravity/gravity_commons.f90 -o gravity_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/chemistry/ionisation_commons.f90 -o ionisation_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/random.f90 -o random.o
# ../src/commons/random.f90:165:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   165 |           SeedArray( I, 1 ) = OutSeed( 1 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# ../src/commons/random.f90:166:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   166 |           SeedArray( I, 2 ) = OutSeed( 2 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# ../src/commons/random.f90:167:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   167 |           SeedArray( I, 3 ) = OutSeed( 3 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# ../src/commons/random.f90:168:21:
#
#   159 |        do I = 2, N
#       |                  2
# ......
#   168 |           SeedArray( I, 4 ) = OutSeed( 4 )
#       |                     1
# Warning: Array reference at (1) out of bounds (2 > 1) in loop beginning at (2)
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/newton_raphson.f90 -o newton_raphson.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/dust/dust_commons.f90 -o dust_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/turb/turb_commons.f90 -o turb_commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/commons.f90 -o commons.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/parameters.f90 -o parameters.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/setups/dustyTurb/units.f90 -o units.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/grid/boundary_types.f90 -o boundary_types.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/slope_limiters.f90 -o slope_limiters.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/allocate_init.f90 -o allocate_init.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/chemistry/ionisation_utils.f90 -o ionisation_utils.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/chemistry/functions_NR.f90 -o functions_NR.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/chemistry/ionisation.f90 -o ionisation.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/grid/grid.f90 -o grid.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/solvers.f90 -o solvers.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/setups/dustyTurb/eos.f90 -o eos.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/setups/dustyTurb/setup.f90 -o setup.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/courant.f90 -o courant.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/godunov.f90 -o godunov.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/setups/dustyTurb/boundaries.f90 -o boundaries.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/write_output.f90 -o write_output.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/read_output.f90 -o read_output.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/source_terms.f90 -o source_terms.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/force_kicks.f90 -o force_kicks.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/dust/dust_init.f90 -o dust_init.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/dust/dust_drag.f90 -o dust_drag.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/dust/dust_growth.f90 -o dust_growth.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/turb/turb_utils.f90 -o turb_utils.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/turb/turb.f90 -o turb.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/gravity/gravity_utils.f90 -o gravity_utils.o
# /Library/Developer/CommandLineTools/usr/bin/make shark
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/solver/solve.f90 -o solve.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/commons/read_params.f90 -o read_params.o
# gfortran -fopenmp  -x f95-cpp-input -O3 -frecord-marker=4 -ffree-line-length-none -DNDUST=1 -DNX=2048 -DNY=1    -DGRIDSPACE=0  -DGEOM=0 -DMHD=1 -DOPENMP=1 -DSOLVER=1 -DSOLVERDUST=2 -DSOLVERB=2 -DNGHOST=2 -DTURB=1 -DGRAVITY=0 -DNDUSTPSCAL=0  -DDUST_PRESSURE=0  -c ../src/shark.f90 -o shark.o
# gfortran -fopenmp  precision.o phys_const.o hydro_commons.o setup_commons.o gravity_commons.o ionisation_commons.o random.o newton_raphson.o  dust_commons.o  turb_commons.o commons.o parameters.o units.o boundary_types.o slope_limiters.o allocate_init.o ionisation_utils.o functions_NR.o ionisation.o grid.o solvers.o eos.o setup.o courant.o godunov.o boundaries.o write_output.o read_output.o source_terms.o force_kicks.o  dust_init.o dust_drag.o dust_growth.o turb_utils.o turb.o gravity_utils.o solve.o read_params.o shark.o -o ./shark
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#    ssss hh   hh     aaa      rrrrrr   kk   kk
#   sss   hh   hh    aa aa     rr  rrr  kk  kk
#    sss  hhhhhhh   aaaaaaa    rrrrr    kk kk
#     sss hh   hh  aaa    aaa  rr  rr   kk  kk
#   ssss  hh   hh aaa      aaa rr    rr kk   kk
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!000!!!!!!!!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!00!!000!!!!!!!!D!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!000!!!!!!!D!!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!000!!!!!!!!!D!!!!!!D!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!00!!!!!!!!!!!D!!!!!!D!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!000!!!!!!!!!!!!D!!!DDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!00000000!!!!!!!!DDDD!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!Ugo Lebreuilly            !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!CEA SACLAY                !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!ugo.lebreuilly@cea.fr     !!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  -------------------------------------------------------------
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#  ------------------------------------------------------------
#                                    /
#                                 ,::|
#                               /::::|
#                              ,:::::\                                      _..
#           ____........-------,..:::::                                   -  /
#   _.--"""". . . .      .   .  .  .  ""`-._                            -  .;
#  <. - :::::O......  ...   . . .. . .  .  .""--._                  ,- . .;
#   `-._  ` `":`:`:`::||||:::::::::::::::::.:. .  ""--._ ,/|     ,- .  .;
#       """_---       // :::.. ````:`:`::::::::::.:.:.:. .`-`._- .   .;
#           ""--.__      (       \               ` ``:`:``:::: .   .;
#                  "\""--.:-.     `.                             .:
#                    \  /    `-._   `.""-----.,-..::(--"".\""`.  `:\
#                     `/         `-._ \          `-:\          `. `:\
#                                     ""            "            `-._)
#   You are using            8  threads
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Namelist reading : DUSTY_TURB_beta1e-1.nml
#  Grid namelist reading  !
#  Dynamics activated
#  Dust namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Dust namelist reading  !
#   Minimal grain size possible :    9.9999999999999995E-008
#   Maximal grain size possible :    1.0000000000000000E-003
#   Grain density               :   2.7000000000000002
#   Dust-to-gas ratio           :   1.0000000000000000E-002
#   Ice mantle                  :   8.7000000000000003E-007
#   MRN dust distribution
#   MRN index             :    3.5000000000000000
#   Minimal grain size    :    4.9999999999999998E-007
#   Maximal grain size    :    2.5000000000000001E-005
#  Growth is deactivated
#  Fragmentation is deactivated
#  charging is not computed
#  physical kernel
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Turb namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  turb_params namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Gravity namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Gravity namelist reading  !
#  Gravity is used
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Ionisation namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  ionisation_params namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Setup namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Setup namelist reading  !
#  ########################################################################################################################################
#  ########################################################################################################################################
#  Namelist reading ok !
#  ########################################################################################################################################
#  ########################################################################################################################################
#         2048  active cells were prepared.
#  Are the indices in order ?
#  irho =           1
#  ivx   =           2
#  ivy  =           3
#  ivz  =           4
#  iBx  =           5
#  iBy  =           6
#  iBz  =           7
#  iP   =           8
#  idust   =           1 irhod =            9  ivdx =           10  ivdy =           11  ivdz =           12
#  Nvar =          12
#  Number of cells        =         2052
#  Number of active cells =         2048
#  You are using a linear cartesian grid.
#  New seed, iseed =            0
#  Initial velocity corrector (solenoidal-xyz) estimated to:    0.0000000000000000
#  Outputing data
#  Total mass is   7.9160003999996450E-015
#  Total momentum is   0.0000000000000000
#  Total energy is   3.0362061375764778E-004
#  time =   83824837572.635086       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9341509912016099E-015
#  Total momentum is  -2.9169680249906348E-012
#  Total energy is   3.0364967188324562E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :         4000  Output            2
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        83824837572.635086
#  timestep is    17485633.824316598
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.9311343867171402      (%) ,  0.31100001465529203       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.229552040816863      (%) ,  0.45900002180133015       seconds
#  Courant                      1.8943614890401597      (%) ,   8.5000004037283361E-002  seconds
#  Predictor step               23.824381550399185      (%) ,   1.0690000507747754       seconds
#  Corrector step               16.313795408904284      (%) ,  0.73200003465171903       seconds
#  Source terms                 11.343882328487544      (%) ,  0.50900002417620271       seconds
#  Dust                         14.397147314110711      (%) ,  0.64600003056693822       seconds
#  Force kick + setup action    15.065745481524115      (%) ,  0.67600003175903112       seconds
#  Running time is    4.4870002124225721       seconds
#  time =   142296649775.68311       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   8.0893929298823782E-015
#  Total momentum is  -3.6880516492742476E-011
#  Total energy is   3.0424232313762872E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :         8000  Output            3
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        142296649775.68311
#  timestep is    12280962.266915180
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.5268588082222081      (%) ,  0.58200002752710134       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.418302120363025      (%) ,  0.92900004412513226       seconds
#  Courant                      1.8616126501402177      (%) ,  0.16600000788457692       seconds
#  Predictor step               23.584165079788420      (%) ,   2.1030000998871401       seconds
#  Corrector step               16.563866771327600      (%) ,   1.4770000700373203       seconds
#  Source terms                 11.416395649655071      (%) ,   1.0180000483524054       seconds
#  Dust                         14.377032634114691      (%) ,   1.2820000607753173       seconds
#  Force kick + setup action    15.251766286388769      (%) ,   1.3600000642472878       seconds
#  Running time is    8.9170004228362814       seconds
#  time =   185187578274.36191       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9981091244474482E-015
#  Total momentum is  -7.4824546821996472E-011
#  Total energy is   3.0410267596824194E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        12000  Output            4
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        185187578274.36191
#  timestep is    9422831.2677886803
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.6251967318433715      (%) ,  0.88400004187133163       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.387469085457210      (%) ,   1.3860000658314675       seconds
#  Courant                      1.7762122462145449      (%) ,  0.23700001125689596       seconds
#  Predictor step               23.637862550888919      (%) ,   3.1540001498069614       seconds
#  Corrector step               16.562991830917152      (%) ,   2.2100001048529521       seconds
#  Source terms                 11.481675785656888      (%) ,   1.5320000727660954       seconds
#  Dust                         14.307127332560285      (%) ,   1.9090000905562192       seconds
#  Force kick + setup action    15.221464436461627      (%) ,   2.0310000961180776       seconds
#  Running time is    13.343000633060001       seconds
#  time =   219109539376.65567       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9656394130972784E-015
#  Total momentum is  -1.0279661624934743E-010
#  Total energy is   3.0405219692448960E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        16000  Output            5
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        219109539376.65567
#  timestep is    7663013.3318373458
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.7037224183392823      (%) ,   1.1940000565955415       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.353152546585346      (%) ,   1.8440000875853002       seconds
#  Courant                      1.7404974454671676      (%) ,  0.31000001472420990       seconds
#  Predictor step               23.620234687356046      (%) ,   4.2070001998217776       seconds
#  Corrector step               16.506653191841458      (%) ,   2.9400001395260915       seconds
#  Source terms                 11.577115266300966      (%) ,   2.0620000979397446       seconds
#  Dust                         14.238392004845538      (%) ,   2.5360001203371212       seconds
#  Force kick + setup action    15.260232439264193      (%) ,   2.7180001287488267       seconds
#  Running time is    17.811000845278613       seconds
#  time =   247225888841.64667       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9495612080593189E-015
#  Total momentum is  -1.2142947716100255E-010
#  Total energy is   3.0402563726634286E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        20000  Output            6
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        247225888841.64667
#  timestep is    6465021.4758283217
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.6872704467002357      (%) ,   1.4930000707972795       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.395950909579032      (%) ,   2.3210001102415845       seconds
#  Courant                      1.7692376601825586      (%) ,  0.39500001876149327       seconds
#  Predictor step               23.716742811814296      (%) ,   5.2950002514990047       seconds
#  Corrector step               16.505419690042434      (%) ,   3.6850001749116927       seconds
#  Source terms                 11.529158828632671      (%) ,   2.5740001222584397       seconds
#  Dust                         14.265878348039196      (%) ,   3.1850001511629671       seconds
#  Force kick + setup action    15.130341305009578      (%) ,   3.3780001600971445       seconds
#  Running time is    22.326001059729606       seconds
#  time =   271268315537.29785       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9388201128212962E-015
#  Total momentum is  -1.3327200353863951E-010
#  Total energy is   3.0400686589071720E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        24000  Output            7
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        271268315537.29785
#  timestep is    5599542.8158368738
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.7664402475585863      (%) ,   1.8130000859964639       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.420243338332405      (%) ,   2.7920001326128840       seconds
#  Courant                      1.7429275211322468      (%) ,  0.46700002218130976       seconds
#  Predictor step               23.714264388167656      (%) ,   6.3540003017988056       seconds
#  Corrector step               16.552213182052700      (%) ,   4.4350002105347812       seconds
#  Source terms                 11.521236097934146      (%) ,   3.0870001466246322       seconds
#  Dust                         14.208404866697130      (%) ,   3.8070001807063818       seconds
#  Force kick + setup action    15.074270358125128      (%) ,   4.0390001914929599       seconds
#  Running time is    26.794001271948218       seconds
#  time =   292298881993.88159       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9307615025755717E-015
#  Total momentum is  -1.4051839410211861E-010
#  Total energy is   3.0399203850385115E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        28000  Output            8
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        292298881993.88159
#  timestep is    4943951.8782998985
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.7666048710177185      (%) ,   2.1170001004356891       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.400818256932924      (%) ,   3.2540001543238759       seconds
#  Courant                      1.7867416736452097      (%) ,  0.55900002655107528       seconds
#  Predictor step               23.681518890943398      (%) ,   7.4090003519086167       seconds
#  Corrector step               16.572908010093755      (%) ,   5.1850002461578697       seconds
#  Source terms                 11.525922138040476      (%) ,   3.6060001712758094       seconds
#  Dust                         14.166080675111925      (%) ,   4.4320002103922889       seconds
#  Force kick + setup action    15.099405484214595      (%) ,   4.7240002240287140       seconds
#  Running time is    31.286001485073939       seconds
#  time =   311006774430.45648       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9244419195145377E-015
#  Total momentum is  -1.4479082484037756E-010
#  Total energy is   3.0397970428749915E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        32000  Output            9
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        311006774430.45648
#  timestep is    4429779.5496744961
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.7468531467032715      (%) ,   2.4120001144474372       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.380419580038726      (%) ,   3.7110001760302112       seconds
#  Courant                      1.7790209790673244      (%) ,  0.63600003020837903       seconds
#  Predictor step               23.661538462154869      (%) ,   8.4590004017809406       seconds
#  Corrector step               16.523076923181730      (%) ,   5.9070002804510295       seconds
#  Source terms                 11.572027972329435      (%) ,   4.1370001964969561       seconds
#  Dust                         14.156643356686512      (%) ,   5.0610002402681857       seconds
#  Force kick + setup action    15.180419579838134      (%) ,   5.4270002574194223       seconds
#  Running time is    35.750001697102562       seconds
#  time =   327870555782.47058       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9193942232075285E-015
#  Total momentum is  -1.4708673132907924E-010
#  Total energy is   3.0396892302805969E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        36000  Output           10
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        327870555782.47058
#  timestep is    4016459.5777875781
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.7327273629024189      (%) ,   2.7110001286491752       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.383450056782081      (%) ,   4.1810001983540133       seconds
#  Courant                      1.8079769533026326      (%) ,  0.72800003457814455       seconds
#  Predictor step               23.645259028014241      (%) ,   9.5210004522232339       seconds
#  Corrector step               16.562360304072502      (%) ,   6.6690003166440874       seconds
#  Source terms                 11.535787016608143      (%) ,   4.6450002206256613       seconds
#  Dust                         14.150896538060337      (%) ,   5.6980002705240622       seconds
#  Force kick + setup action    15.181542740257644      (%) ,   6.1130002900026739       seconds
#  Running time is    40.266001911601052       seconds
#  time =   343236156892.79437       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9154881453850445E-015
#  Total momentum is  -1.4814789840453706E-010
#  Total energy is   3.0395910649730926E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        40000  Output           11
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        343236156892.79437
#  timestep is    3677031.5012057540
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.7209593698455752      (%) ,   3.0040001425659284       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.425988902506418      (%) ,   4.6600002211052924       seconds
#  Courant                      1.8167173796691416      (%) ,  0.81200003856793046       seconds
#  Predictor step               23.606139252326493      (%) ,   10.551000501145609       seconds
#  Corrector step               16.580902094232162      (%) ,   7.4110003518871963       seconds
#  Source terms                 11.551369250285441      (%) ,   5.1630002452293411       seconds
#  Dust                         14.115357078966898      (%) ,   6.3090002995450050       seconds
#  Force kick + setup action    15.182566672167875      (%) ,   6.7860003219684586       seconds
#  Running time is    44.696002122014761       seconds
#  time =   357360381901.32977       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9127388044610308E-015
#  Total momentum is  -1.4848978974606782E-010
#  Total energy is   3.0394985001481654E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        44000  Output           12
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        357360381901.32977
#  timestep is    3393212.5015009916
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.7301626064803806      (%) ,   3.3070001569576561       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.448338319116912      (%) ,   5.1340002436190844       seconds
#  Courant                      1.8336487779414232      (%) ,  0.90100004279520363       seconds
#  Predictor step               23.503673403380134      (%) ,   11.549000548548065       seconds
#  Corrector step               16.639192461970715      (%) ,   8.1760003882227466       seconds
#  Source terms                 11.526955247791589      (%) ,   5.6640002690255642       seconds
#  Dust                         14.152268148269915      (%) ,   6.9540003301808611       seconds
#  Force kick + setup action    15.165761035048936      (%) ,   7.4520003536017612       seconds
#  Running time is    49.137002332950942       seconds
#  time =   370436055990.93329       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9105824048589182E-015
#  Total momentum is  -1.4839703195494070E-010
#  Total energy is   3.0394141891337725E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        48000  Output           13
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        370436055990.93329
#  timestep is    3150385.6172749633
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.7705805487150288      (%) ,   3.6270001721568406       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.427478065828415      (%) ,   5.5860002650879323       seconds
#  Courant                      1.8163151017676231      (%) ,  0.97300004621502012       seconds
#  Predictor step               23.487026321110211      (%) ,   12.582000597612932       seconds
#  Corrector step               16.636176964790966      (%) ,   8.9120004231808707       seconds
#  Source terms                 11.545641217299845      (%) ,   6.1850002937717363       seconds
#  Dust                         14.140377076750566      (%) ,   7.5750003596767783       seconds
#  Force kick + setup action    15.176404703737346      (%) ,   8.1300003858050331       seconds
#  Running time is    53.570002543507144       seconds
#  time =   382609848939.38141       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9089845351406051E-015
#  Total momentum is  -1.4814521263803618E-010
#  Total energy is   3.0393515609010592E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        52000  Output           14
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        382609848939.38141
#  timestep is    2941810.9362121434
#  Time spent in each routines: cumulative percentage & real time of current timestep & real time cumulative
#  Boundaries + ctoprim         6.7806542796144900      (%) ,   3.9340001867385581       seconds
#  Forces                       0.0000000000000000      (%) ,   0.0000000000000000       seconds
#  Charging + stoping time      10.431245475308211      (%) ,   6.0520002872217447       seconds
#  Courant                      1.8184011858680671      (%) ,   1.0550000501098111       seconds
#  Predictor step               23.477196732425536      (%) ,   13.621000646962784       seconds
#  Corrector step               16.632769140677876      (%) ,   9.6500004582339898       seconds
#  Source terms                 11.546416629507281      (%) ,   6.6990003181854263       seconds
#  Dust                         14.140439174075766      (%) ,   8.2040003895526752       seconds
#  Force kick + setup action    15.172877382522772      (%) ,   8.8030004177708179       seconds
#  Running time is    58.018002754775807       seconds
#  time =   394007859962.63153       tend =    1500000000000.0000
#  Outputing data
#  Total mass is   7.9076375467015222E-015
#  Total momentum is  -1.4790249786876736E-010
#  Total energy is   3.0393031172627760E-004
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  Outputing the Time step :        56000  Output           15
#  ************************************************************************************
#  ************************************************************************************
#  ************************************************************************************
#  time is        394007859962.63153
#  timestep is    2761382.1986397584
# ...
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4917073408155.19
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1031
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4918504696715.99
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1032
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4919933329997.53
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1033
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4921359274353.97
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1034
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4922782500149.13
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1035
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4924202975296.32
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1036
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4925620668406.73
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1037
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4927035551535.19
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1038
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4928447598608.62
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1039
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4929856781973.68
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1040
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4931263082567.74
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1041
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4932666479242.95
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1042
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4934066959804.74
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1043
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4935464508635.36
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1044
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4936859114629.63
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1045
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4938250770947.04
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1046
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4939639469590.5
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1047
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4941025210811.85
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1048
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4942407997279.17
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1049
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4943787837525.99
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1050
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4945164741030.54
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1051
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4946538721636.89
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1052
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4947909799825.08
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1053
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4949277989504.1
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1054
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4950643322116.1
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1055
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4952005826705.13
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1056
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4953365539187.41
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1057
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4954722491382.58
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1058
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4956076722026.42
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1059
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4957428271651.7
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1060
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4958777182589.6
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1061
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4960123497558.39
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1062
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4961467262804.04
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1063
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4962808537148.81
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1064
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4964147365267.88
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1065
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4965483795555.13
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1066
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4966817882607.42
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1067
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4968149678455.77
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1068
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4969479231879.94
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1069
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4970806592786.58
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1070
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4972131812710.21
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1071
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4973454945759.49
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1072
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4974776045588.09
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1073
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4976095160056.49
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1074
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4977412343555.2
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1075
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4978727649566.83
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1076
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4980041129463.11
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1077
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4981352837723.71
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1078
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4982662826607.37
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1079
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4983971138919.33
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1080
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4985277817011.12
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1081
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4986582904917.76
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1082
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4987886441732.81
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1083
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4989188471810.72
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1084
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4990489035967.78
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1085
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4991788173007.01
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1086
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4993085920854.56
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1087
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4994382314507.33
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1088
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4995677391862.88
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1089
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4996971186927.11
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1090
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4998263732869.89
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1091
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  4999555061326.06
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
# Reading output 1092
# nvar =  12
# ndust =  1
# ndustpscal =  0
# NX =  2048
# NY =  1
# MHD =  1
# GEOM =  0
# TURB =  1
# GRIDSPACE =  0
# time =  5000000293319.43
# unit_t =  1.0
# unit_d =  1.0
# unit_l =  1.0
# unit_v =  1.0
# unit_p =  1.0
# charging =  1
# call_electric_field =  0
